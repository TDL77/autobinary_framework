# %% [markdown]
# # Демонстрация автоматического расчета PDP

# %% [raw]
# #!pip install PDPbox-0.2.0.tar.gz

# %%
import pdpbox
print(pdpbox.__version__)
# Out:
# 0.2.0

# %%
# расширяем поле, убираем предупреждения
from IPython.core.display import display, HTML
display(HTML('<style>.container {width:95% !important;}</style>'))

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container {width:95% !important;}</style>

# %%
# Стандартные библиотеки для анализа
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import xgboost as xgb

import matplotlib.pylab as pl

# %%
import sys
sys.path.append('../')

# Наша разработанная библиотека
from autobinary import SentColumns, CatBoostEncoder, PlotShap, PlotPDP, BalanceCover, base_pipe

# %% [markdown]
# * sklearn:  0.24.2
# * xgboost:  1.5.2
# * matplotlib:  3.1.1
# * autobinary:  1.0.3

# %%
import sklearn as sk
import xgboost as xgb
import matplotlib as mplot
import autobinary as ab

print('sklearn: ', sk.__version__)
print('xgboost: ', xgb.__version__)
print('matplotlib: ', mplot.__version__)
print('autobinary: ', ab.__version__)
# Out:
# sklearn:  1.0.2
# xgboost:  1.5.2
# matplotlib:  3.5.1
# autobinary:  1.0.6

# %%
sample = pd.read_csv('../data/train_titanic.csv')

print('Размерность данных:', sample.shape)
sample.head(2)
# Out:
# Размерность данных: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
num_columns = [
    'Age', 'Fare'
]

cat_columns = [
    'Pclass', 'Sex', 'Embarked', 'SibSp', 'Parch'
]

target = ['Survived']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    sample,
    sample[target],
    test_size=0.3,
    stratify=sample[target],
    random_state=42
)

# %%
prep_pipe = base_pipe(
    num_columns=num_columns, 
    cat_columns=cat_columns)
# Out:
# Определены количественные и категориальные переменные!

# %%
prep_pipe.fit(X_train, y_train)

new_X_train = prep_pipe.transform(X_train)
new_X_valid = prep_pipe.transform(X_valid)

# %%
# создаем экземпляр класса XGBClassifier
xgb_model = xgb.XGBClassifier(
    eta=0.01,
    n_estimators=800,
    subsample=0.9,
    colsample_bytree=0.6,
    max_depth = 6,
    objective='binary:logistic',
    use_label_encoder=False,
    n_jobs=-1,
    random_state=42)

# %%
xgb_model.fit(new_X_train, y_train);
# Out:
# [12:04:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## Кастомная метрика

# %%
df_train = pd.DataFrame()
df_train['target'] = y_train
df_train['proba'] = xgb_model.predict_proba(new_X_train)[:, 1]
df_train = df_train.sort_values('proba', ascending=False).reset_index(drop=True)

df_valid = pd.DataFrame()
df_valid['target'] = y_valid
df_valid['proba'] = xgb_model.predict_proba(new_X_valid)[:, 1]
df_valid = df_valid.sort_values('proba', ascending=False).reset_index(drop=True)

# %%
metr_train = BalanceCover(df_train, target='target')
metr_train.calc_scores(30, df_train.shape[0])

# %%
metr_train.sample_describe()
metr_train.plot_scores()
# Out:
# Всего записей в выборке:  623
# Всего таргетов в выборке:  239

# %%
metr_train.output
# Out:
#     start_bucket  end_bucket  turget_in_bucket  bucket_bal (%)  coverage (%)  \
# 0              0          30                30      100.000000     12.552301
# 1              0          60                60      100.000000     25.104603
# 2              0          90                90      100.000000     37.656904
# 3              0         120               120      100.000000     50.209205
# 4              0         150               149       99.333333     62.343096
# 5              0         180               178       98.888889     74.476987
# 6              0         210               199       94.761905     83.263598
# 7              0         240               214       89.166667     89.539749
# 8              0         270               224       82.962963     93.723849
# 9              0         300               229       76.333333     95.815900
# 10             0         330               232       70.303030     97.071130
# 11             0         360               235       65.277778     98.326360
# 12             0         390               238       61.025641     99.581590
# 13             0         420               238       56.666667     99.581590
# 14             0         450               239       53.111111    100.000000
# 15             0         480               239       49.791667    100.000000
# 16             0         510               239       46.862745    100.000000
# 17             0         540               239       44.259259    100.000000
# 18             0         570               239       41.929825    100.000000
# 19             0         600               239       39.833333    100.000000
# 20             0         630               239       37.936508    100.000000
#
#     base_bal (%)  bucket_bal/base_bal         auc
# 0      38.362761             2.606695  100.000000
# 1      38.362761             2.606695  100.000000
# 2      38.362761             2.606695  100.000000
# 3      38.362761             2.606695  100.000000
# 4      38.362761             2.589317   93.624161
# 5      38.362761             2.577731   86.095506
# 6      38.362761             2.470153   93.033349
# 7      38.362761             2.324303   92.631201
# 8      38.362761             2.162591   92.236025
# 9      38.362761             1.989777   93.335999
# 10     38.362761             1.832585   94.066678
# 11     38.362761             1.701592   94.279149
# 12     38.362761             1.590752   94.183989
# 13     38.362761             1.477127   95.142672
# 14     38.362761             1.384444   95.454005
# 15     38.362761             1.297917   96.019896
# 16     38.362761             1.221569   96.460498
# 17     38.362761             1.153704   96.813272
# 18     38.362761             1.092982   97.102100
# 19     38.362761             1.038333   97.342922
# 20     38.362761             0.988889   97.502070

# %%
metr_valid = BalanceCover(df_valid, target='target')
metr_valid.calc_scores(30, df_valid.shape[0])

# %%
metr_valid.sample_describe()
metr_valid.plot_scores()
# Out:
# Всего записей в выборке:  268
# Всего таргетов в выборке:  103

# %%
metr_valid.output
# Out:
#    start_bucket  end_bucket  turget_in_bucket  bucket_bal (%)  coverage (%)  \
# 0             0          30                29       96.666667     28.155340
# 1             0          60                54       90.000000     52.427184
# 2             0          90                70       77.777778     67.961165
# 3             0         120                81       67.500000     78.640777
# 4             0         150                86       57.333333     83.495146
# 5             0         180                93       51.666667     90.291262
# 6             0         210                98       46.666667     95.145631
# 7             0         240                99       41.250000     96.116505
# 8             0         270               103       38.148148    100.000000
#
#    base_bal (%)  bucket_bal/base_bal        auc
# 0     38.432836             2.515210  48.275862
# 1     38.432836             2.341748  70.987654
# 2     38.432836             2.023732  80.214286
# 3     38.432836             1.756311  80.800886
# 4     38.432836             1.491780  84.947311
# 5     38.432836             1.344337  83.728835
# 6     38.432836             1.214239  83.550474
# 7     38.432836             1.073301  86.206032
# 8     38.432836             0.992593  85.151515

# %% [markdown]
# ## Использование библиотеки PDP

# %%
# Задаем необходимые факторы для анализа, в нужном нам порядке

feats = ['Age','Fare', 'Sex', 'Pclass']

# %%
# Задаем класс PlotPDP(model - 'наша модель', 
##                   X - 'датасет на котором обучалась модель',
##                   main_features - 'список факторов необходимых для анализа')

pdp_plot = PlotPDP(model=xgb_model,X=new_X_train,main_features=feats)

# %%
# Выводим графики по каждому фактору функцией create_feature_plot(save = True/False - 'Сохранить/не сохранять графики',
##                                                           frac_to_plot = 0.1 - 'доля сэмпла для анализа, по умолчанию 10%',
##                                                           n_jobs = -1,
##                                                           path = './pdp_ice_plots' - 'директория куда будут сохранены графики')

pdp_plot.create_feature_plot(save=True, frac_to_plot=0.05)
# Out:
# Age
# Fare
# Sex
# Pclass

# %%
pdp_plot.create_interact_plot(features=['Age','Fare'], save=True)
# Out:
# Интерпретация: Как факторы  ['Age', 'Fare'] совместо влияют на предсказание. Чем ярчке (желтая) ячейка, тем сильнее влияние в совокупности: Для классификации - растет вероятность отнесения к целевой метке класса; Для регрессии - растет значение предсказания. Чем темнее (фиолетовая) ячейка - обратная ситуация.

# %%
# Генерация html отчета PDP-ICE plots функцией create_pdp_report(path_base = './pdp_ice_plots' - 'необходимая директория для графиков/отчета')

pdp_plot.create_pdp_report()
# Out:
# Загрузка всех сохраненных изображений
#
# Загрузка завершена.
#
# Отчет сгенерирован.
